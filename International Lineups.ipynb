# %%
import pandas as pd
from statistics import mean

# %%
fifa_18 = pd.read_csv("players_18.csv")
fifa_18.head()
# Out:
#    sofifa_id                                         player_url  \
# 0      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 1     158023  https://sofifa.com/player/158023/lionel-messi/...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     167495  https://sofifa.com/player/167495/manuel-neuer/...
# 4     176580  https://sofifa.com/player/176580/luis-suarez/1...
#
#           short_name                            long_name  age         dob  \
# 0  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   32  1985-02-05
# 1           L. Messi       Lionel Andrés Messi Cuccittini   30  1987-06-24
# 2             Neymar        Neymar da Silva Santos Junior   25  1992-02-05
# 3           M. Neuer                         Manuel Neuer   31  1986-03-27
# 4          L. Suárez             Luis Alberto Suárez Díaz   30  1987-01-24
#
#    height_cm  weight_kg nationality                 club  ...   lwb   ldm  \
# ...

# %%
fifa_18 = fifa_18.drop(["sofifa_id", "player_url", "long_name","dob", "potential", "value_eur", "wage_eur", "international_reputation", "body_type", "real_face", "release_clause_eur", "player_tags", "loaned_from", "joined", "contract_valid_until", "height_cm", "weak_foot", "skill_moves", "work_rate", "team_jersey_number", "weight_kg", "age", "player_positions"], axis = 1)
fifa_18 = fifa_18.iloc[:, range(0, 17)]
fifa_18 = fifa_18.rename(columns = {"short_name": "name", "team_position": "position", "physic":"physical"})

# %%
fifa_18.loc[fifa_18.position == "LCM", "position"] = "CM"
fifa_18.loc[fifa_18.position == "RCM", "position"] = "CM"
fifa_18.loc[fifa_18.position == "LCB", "position"] = "CB"
fifa_18.loc[fifa_18.position == "RCB", "position"] = "CB"
fifa_18.loc[fifa_18.position == "RDM", "position"] = "CDM"
fifa_18.loc[fifa_18.position == "LDM", "position"] = "CDM"
fifa_18.loc[fifa_18.position == "RAM", "position"] = "CAM"
fifa_18.loc[fifa_18.position == "LAM", "position"] = "CAM"
fifa_18.loc[fifa_18.position == "LS", "position"] = "ST"
fifa_18.loc[fifa_18.position == "RS", "position"] = "ST"

# %%
fifa_18.loc[fifa_18.nation_position == "LCM", "nation_position"] = "CM"
fifa_18.loc[fifa_18.nation_position == "RCM", "nation_position"] = "CM"
fifa_18.loc[fifa_18.nation_position == "LCB", "nation_position"] = "CB"
fifa_18.loc[fifa_18.nation_position == "RCB", "nation_position"] = "CB"
fifa_18.loc[fifa_18.nation_position == "RDM", "nation_position"] = "CDM"
fifa_18.loc[fifa_18.nation_position == "LDM", "nation_position"] = "CDM"
fifa_18.loc[fifa_18.nation_position == "RAM", "nation_position"] = "CAM"
fifa_18.loc[fifa_18.nation_position == "LAM", "nation_position"] = "CAM"
fifa_18.loc[fifa_18.nation_position == "LS", "nation_position"] = "ST"
fifa_18.loc[fifa_18.nation_position == "RS", "nation_position"] = "ST"

# %%
russia_lineup = ["F. Smolov", "A. Dzagoev", "A. Samedov", "A. Golovin", "Y. Gazinskiy", "R. Zobnin", "Mário Fernandes", "I. Kutepov", "S. Ignashevich", "Y. Zhirkov", "I. Akinfeev", "D. Cheryshev", "I. Smolnikov", "D. Kuzyaev"]
fifa_18.loc[fifa_18.name == russia_lineup[0], "nation_position"] = "ST"
fifa_18.loc[fifa_18.name == russia_lineup[1], "nation_position"] = "CAM"
fifa_18.loc[fifa_18.name == russia_lineup[2], "nation_position"] = "LW"
fifa_18.loc[fifa_18.name == russia_lineup[3], "nation_position"] = "RW"
fifa_18.loc[fifa_18.name == russia_lineup[4], "nation_position"] = "CDM"
fifa_18.loc[fifa_18.name == russia_lineup[5], "nation_position"] = "CDM"
fifa_18.loc[fifa_18.name == russia_lineup[6], "nation_position"] = "RB"
fifa_18.loc[fifa_18.name == russia_lineup[7], "nation_position"] = "CB"
fifa_18.loc[fifa_18.name == russia_lineup[8], "nation_position"] = "CB"
fifa_18.loc[fifa_18.name == russia_lineup[9], "nation_position"] = "LB"
fifa_18.loc[fifa_18.name == russia_lineup[10], "nation_position"] = "GK"
fifa_18.loc[fifa_18.name == russia_lineup[11], "nation_position"] = "SUB"
fifa_18.loc[fifa_18.name == russia_lineup[12], "nation_position"] = "SUB"
fifa_18.loc[fifa_18.name == russia_lineup[13], "nation_position"] = "SUB"
russia = fifa_18.loc[fifa_18.name.isin(russia_lineup)]

# %%
portugal_lineup = ["Gonçalo Guedes", "Cristiano Ronaldo", "Bruno Fernandes", "William Carvalho", "João Moutinho", "Bernardo Silva", "R.Guerreiro", "José Fonte", "Pepe", "Cédric", "Rui Patrício", "Quaresma", "André Silva", "João Mário"]
fifa_18.loc[fifa_18.name == portugal_lineup[0], "nation_position"] = "ST"
fifa_18.loc[fifa_18.name == portugal_lineup[1], "nation_position"] = "ST"
fifa_18.loc[fifa_18.name == portugal_lineup[2], "nation_position"] = "LW"
fifa_18.loc[fifa_18.name == portugal_lineup[3], "nation_position"] = "CM"
fifa_18.loc[fifa_18.name == portugal_lineup[4], "nation_position"] = "CM"
fifa_18.loc[fifa_18.name == portugal_lineup[5], "nation_position"] = "RW"
fifa_18.loc[fifa_18.name == portugal_lineup[6], "nation_position"] = "RB"
fifa_18.loc[fifa_18.name == portugal_lineup[7], "nation_position"] = "CB"
fifa_18.loc[fifa_18.name == portugal_lineup[8], "nation_position"] = "CB"
fifa_18.loc[fifa_18.name == portugal_lineup[9], "nation_position"] = "LB"
fifa_18.loc[fifa_18.name == portugal_lineup[10], "nation_position"] = "GK"
fifa_18.loc[fifa_18.name == portugal_lineup[11], "nation_position"] = "SUB"
fifa_18.loc[fifa_18.name == portugal_lineup[12], "nation_position"] = "SUB"
fifa_18.loc[fifa_18.name == portugal_lineup[13], "nation_position"] = "SUB"

# %%
spain_lineup = ["Diego Costa", "Isco", "David Silva", "Thiago", "Sergio Busquets", "Koke", "Nacho Fernández", "Piqué", "Sergio Ramos", "Jordi Alba", "De Gea", "Lucas Vázques", "Iago Aspas", "Marco Asensio"]
fifa_18.loc[fifa_18.name == spain_lineup[0], "nation_position"] = "ST"
fifa_18.loc[fifa_18.name == spain_lineup[1], "nation_position"] = "LW"
fifa_18.loc[fifa_18.name == spain_lineup[2], "nation_position"] = "RW"
fifa_18.loc[fifa_18.name == spain_lineup[3], "nation_position"] = "CM"
fifa_18.loc[fifa_18.name == spain_lineup[4], "nation_position"] = "CM"
fifa_18.loc[fifa_18.name == spain_lineup[5], "nation_position"] = "CM"
fifa_18.loc[fifa_18.name == spain_lineup[6], "nation_position"] = "RB"
fifa_18.loc[fifa_18.name == spain_lineup[7], "nation_position"] = "CB"
fifa_18.loc[fifa_18.name == spain_lineup[8], "nation_position"] = "CB"
fifa_18.loc[fifa_18.name == spain_lineup[9], "nation_position"] = "LB"
fifa_18.loc[fifa_18.name == spain_lineup[10], "nation_position"] = "GK"
fifa_18.loc[fifa_18.name == spain_lineup[11], "nation_position"] = "SUB"
fifa_18.loc[fifa_18.name == spain_lineup[12], "nation_position"] = "SUB"
fifa_18.loc[fifa_18.name == spain_lineup[13], "nation_position"] = "SUB"

# %%
sweden_lineup = ["M. Berg", "O. Toivonen", "E. Forsberg", "A. Ekdal", "S. Larrson", "V. Claesson", "M. Lustig", "P. Jansson", "A. Granqvist", "L. Augustinsson", "R. Olsen", "G. Svensson", "O. Hiljemark", "I. Kiese Thelin"]
fifa_18.loc[fifa_18.name == sweden_lineup[0], "nation_position"] = "ST"
fifa_18.loc[fifa_18.name == sweden_lineup[1], "nation_position"] = "ST"
fifa_18.loc[fifa_18.name == sweden_lineup[2], "nation_position"] = "LW"
fifa_18.loc[fifa_18.name == sweden_lineup[3], "nation_position"] = "CM"
fifa_18.loc[fifa_18.name == sweden_lineup[4], "nation_position"] = "CM"
fifa_18.loc[fifa_18.name == sweden_lineup[5], "nation_position"] = "RW"
fifa_18.loc[fifa_18.name == sweden_lineup[6], "nation_position"] = "RB"
fifa_18.loc[fifa_18.name == sweden_lineup[7], "nation_position"] = "CB"
fifa_18.loc[fifa_18.name == sweden_lineup[8], "nation_position"] = "CB"
fifa_18.loc[fifa_18.name == sweden_lineup[9], "nation_position"] = "LB"
fifa_18.loc[fifa_18.name == sweden_lineup[10], "nation_position"] = "GK"
fifa_18.loc[fifa_18.name == sweden_lineup[11], "nation_position"] = "SUB"
fifa_18.loc[fifa_18.name == sweden_lineup[12], "nation_position"] = "SUB"
fifa_18.loc[fifa_18.name == sweden_lineup[13], "nation_position"] = "SUB"

# %%
skorea_lineup = ["H. Son", "Kim Shin Wook", "Hwang Hee Chan", "Koo Ja Cheol", "Ki Sung Yueng", "Lee Jae Sung", "Park Joo Ho", "Kim Yong Hwan", "Jang Hyeon Soo", "Lee Chung Yong", "Cho Hyun Woo", "Lee Seung Woo", "Kim Min Woo", "Jung Woo Jae"]
fifa_18.loc[fifa_18.name == skorea_lineup[0], "nation_position"] = "LW"
fifa_18.loc[fifa_18.name == skorea_lineup[1], "nation_position"] = "ST"
fifa_18.loc[fifa_18.name == skorea_lineup[2], "nation_position"] = "RW"
fifa_18.loc[fifa_18.name == skorea_lineup[3], "nation_position"] = "CM"
fifa_18.loc[fifa_18.name == skorea_lineup[4], "nation_position"] = "CM"
fifa_18.loc[fifa_18.name == skorea_lineup[5], "nation_position"] = "CM"
fifa_18.loc[fifa_18.name == skorea_lineup[6], "nation_position"] = "LB"
fifa_18.loc[fifa_18.name == skorea_lineup[7], "nation_position"] = "CB"
fifa_18.loc[fifa_18.name == skorea_lineup[8], "nation_position"] = "CB"
fifa_18.loc[fifa_18.name == skorea_lineup[9], "nation_position"] = "RB"
fifa_18.loc[fifa_18.name == skorea_lineup[10], "nation_position"] = "GK"
fifa_18.loc[fifa_18.name == skorea_lineup[11], "nation_position"] = "SUB"
fifa_18.loc[fifa_18.name == skorea_lineup[12], "nation_position"] = "SUB"
fifa_18.loc[fifa_18.name == skorea_lineup[13], "nation_position"] = "SUB"

# %%
belgium_lineup = ["R. Lukaku", "D. Mertens", "E. Hazard", "T. Meunier", "K. De Bruyne", "A. Witsel", "Y. Carrasco", "J. Vertonghen", "D. Boyata", "T.Alderweireld", "T. Courtois", "T. Hazard", "M. Dembélé", "N. Chadli"]
fifa_18.loc[fifa_18.name == belgium_lineup[0], "nation_position"] = "ST"
fifa_18.loc[fifa_18.name == belgium_lineup[1], "nation_position"] = "CAM"
fifa_18.loc[fifa_18.name == belgium_lineup[2], "nation_position"] = "CAM"
fifa_18.loc[fifa_18.name == belgium_lineup[3], "nation_position"] = "RW"
fifa_18.loc[fifa_18.name == belgium_lineup[4], "nation_position"] = "CM"
fifa_18.loc[fifa_18.name == belgium_lineup[5], "nation_position"] = "CM"
fifa_18.loc[fifa_18.name == belgium_lineup[6], "nation_position"] = "LW"
fifa_18.loc[fifa_18.name == belgium_lineup[7], "nation_position"] = "LB"
fifa_18.loc[fifa_18.name == belgium_lineup[8], "nation_position"] = "CB"
fifa_18.loc[fifa_18.name == belgium_lineup[9], "nation_position"] = "RB"
fifa_18.loc[fifa_18.name == belgium_lineup[10], "nation_position"] = "GK"
fifa_18.loc[fifa_18.name == belgium_lineup[11], "nation_position"] = "SUB"
fifa_18.loc[fifa_18.name == belgium_lineup[12], "nation_position"] = "SUB"
fifa_18.loc[fifa_18.name == belgium_lineup[13], "nation_position"] = "SUB"

# %%
portugal = fifa_18.loc[fifa_18["nationality"] == "Panama"]
pd.set_option('display.max_rows', portugal.shape[0]+1)
portugal
# Out:
#               name nationality                  club  overall preferred_foot  \
# 4255      A. Godoy      Panama  San Jose Earthquakes       71           Left
# 4663    A. Machado      Panama        Houston Dynamo       71          Right
# 5413      G. Gómez      Panama  Atlético Bucaramanga       70          Right
# 5625     R. Torres      Panama   Seattle Sounders FC       70          Right
# 7306     G. Torres      Panama     FC Lausanne-Sport       68          Right
# 8560     A. Cooper      Panama            Toronto FC       67          Right
# 9008   H. Cummings      Panama  San Jose Earthquakes       66          Right
# 9961        J. Cox      Panama           Envigado FC       65          Right
# 10089   J. Aguilar      Panama         Estoril Praia       65           Left
# 10091   F. Escobar      Panama    New York Red Bulls       65          Right
# 11255   M. Murillo      Panama    New York Red Bulls       64          Right
# ...

# %%
panama_lineup = ["J. Cox", "", "A. Godoy", "A. Cooper", "F. Escobar", "R. Torres", ""]
fifa_18.loc[fifa_18.name == panama_lineup[0], "nation_position"] = "ST"
fifa_18.loc[fifa_18.name == panama_lineup[1], "nation_position"] = "CAM"
fifa_18.loc[fifa_18.name == panama_lineup[2], "nation_position"] = "CAM"
fifa_18.loc[fifa_18.name == panama_lineup[3], "nation_position"] = "RW"
fifa_18.loc[fifa_18.name == panama_lineup[4], "nation_position"] = "CM"
fifa_18.loc[fifa_18.name == panama_lineup[5], "nation_position"] = "CM"
fifa_18.loc[fifa_18.name == panama_lineup[6], "nation_position"] = "LW"
fifa_18.loc[fifa_18.name == panama_lineup[7], "nation_position"] = "LB"
fifa_18.loc[fifa_18.name == panama_lineup[8], "nation_position"] = "CB"
fifa_18.loc[fifa_18.name == panama_lineup[9], "nation_position"] = "RB"
fifa_18.loc[fifa_18.name == panama_lineup[10], "nation_position"] = "GK"
fifa_18.loc[fifa_18.name == panama_lineup[11], "nation_position"] = "SUB"
fifa_18.loc[fifa_18.name == panama_lineup[12], "nation_position"] = "SUB"
fifa_18.loc[fifa_18.name == panama_lineup[13], "nation_position"] = "SUB"

# %%
# Out:
#                     name nationality                         club  overall  \
# 787            W. Khazri     Tunisia             Stade Rennais FC       78
# 1035        A. Abdennour     Tunisia       Olympique de Marseille       77
# 1916       Y. Benalouane     Tunisia               Leicester City       75
# 2109           E. Skhiri     Tunisia              Montpellier HSC       74
# 3536            N. Sliti     Tunisia                    Dijon FCO       72
# 3584      S. Ben Youssef     Tunisia                 Kasimpaşa SK       72
# 3618            A. Yahia     Tunisia            AS Nancy Lorraine       72
# 3737          S. Allagui     Tunisia                 FC St. Pauli       72
# 3820         H. Harbaoui     Tunisia               RSC Anderlecht       72
# 4384   F. Ben Khalfallah     Tunisia                Brisbane Roar       71
# 4711          A. Akaichi     Tunisia                   Al Ittihad       71
# ...

# %%
tunisia_lineup = ["W. Khazri", "A. Oueslati", "B. Srarfi", "K. Laribi", "N. Sliti", "E. Skhiti", "D. Bronn", "S. Ben Youssef","K. Haggui", "O. Haddadi", "F. Ben Mustapha", "Y. Benalouane", "A. Abdennour", "S. Allagui"]
fifa_18.loc[fifa_18.name == tunisia_lineup[0], "nation_position"] = "ST"
fifa_18.loc[fifa_18.name == tunisia_lineup[1], "nation_position"] = "RW"
fifa_18.loc[fifa_18.name == tunisia_lineup[2], "nation_position"] = "CM"
fifa_18.loc[fifa_18.name == tunisia_lineup[3], "nation_position"] = "CM"
fifa_18.loc[fifa_18.name == tunisia_lineup[4], "nation_position"] = "LW"
fifa_18.loc[fifa_18.name == tunisia_lineup[5], "nation_position"] = "CDM"
fifa_18.loc[fifa_18.name == tunisia_lineup[6], "nation_position"] = "RB"
fifa_18.loc[fifa_18.name == tunisia_lineup[7], "nation_position"] = "CB"
fifa_18.loc[fifa_18.name == tunisia_lineup[8], "nation_position"] = "CB"
fifa_18.loc[fifa_18.name == tunisia_lineup[9], "nation_position"] = "LB"
fifa_18.loc[fifa_18.name == tunisia_lineup[10], "nation_position"] = "GK"
fifa_18.loc[fifa_18.name == tunisia_lineup[11], "nation_position"] = "SUB"
fifa_18.loc[fifa_18.name == tunisia_lineup[12], "nation_position"] = "SUB"
fifa_18.loc[fifa_18.name == tunisia_lineup[13], "nation_position"] = "SUB"

# %%
# Out:
#                         name nationality                        club  overall  \
# 47                   H. Kane     England           Tottenham Hotspur       86
# 94                   D. Alli     England           Tottenham Hotspur       84
# 113                G. Cahill     England                     Chelsea       84
# 155                K. Walker     England             Manchester City       83
# 181               A. Lallana     England                   Liverpool       83
# 209                  E. Dier     England           Tottenham Hotspur       82
# 211              R. Sterling     England             Manchester City       82
# 229             J. Henderson     England                   Liverpool       82
# 232                 N. Clyne     England                   Liverpool       82
# 235                  D. Rose     England           Tottenham Hotspur       82
# 250                  J. Hart     England             West Ham United       82
# ...

# %%
england_lineup = ["H.Kane", "R. Sterling", "D. Alli", "J. Lingard", "A. Young", "K. Trippier", "J. Henderson", "H. Maguire", "J. Stones", "K. Walker", "J. Pickford", "E. Dier", "M. Rashford", "R. Loftus-Cheek"]
fifa_18.loc[fifa_18.name == england_lineup[0], "nation_position"] = "ST"
fifa_18.loc[fifa_18.name == england_lineup[1], "nation_position"] = "ST"
fifa_18.loc[fifa_18.name == england_lineup[2], "nation_position"] = "LW"
fifa_18.loc[fifa_18.name == england_lineup[3], "nation_position"] = "CM"
fifa_18.loc[fifa_18.name == england_lineup[4], "nation_position"] = "CM"
fifa_18.loc[fifa_18.name == england_lineup[5], "nation_position"] = "RW"
fifa_18.loc[fifa_18.name == england_lineup[6], "nation_position"] = "CDM"
fifa_18.loc[fifa_18.name == england_lineup[7], "nation_position"] = "LB"
fifa_18.loc[fifa_18.name == england_lineup[8], "nation_position"] = "CB"
fifa_18.loc[fifa_18.name == england_lineup[9], "nation_position"] = "RB"
fifa_18.loc[fifa_18.name == england_lineup[10], "nation_position"] = "GK"
fifa_18.loc[fifa_18.name == england_lineup[11], "nation_position"] = "SUB"
fifa_18.loc[fifa_18.name == england_lineup[12], "nation_position"] = "SUB"
fifa_18.loc[fifa_18.name == england_lineup[13], "nation_position"] = "SUB"

# %%
# Out:
#                      name nationality                         club  overall  \
# 49           J. Rodríguez    Colombia            FC Bayern München       86
# 115                Falcao    Colombia                    AS Monaco       84
# 287           J. Cuadrado    Colombia                     Juventus       82
# 295              C. Bacca    Colombia                Villarreal CF       82
# 301            D. Sánchez    Colombia            Tottenham Hotspur       81
# 424             L. Muriel    Colombia                   Sevilla FC       80
# 561            J. Murillo    Colombia                  Valencia CF       79
# 653             D. Ospina    Colombia                      Arsenal       79
# 759             D. Zapata    Colombia                    Sampdoria       78
# 778          J. Izquierdo    Colombia       Brighton & Hove Albion       78
# 851              A. Ramos    Colombia                   Granada CF       78
# ...

# %%
columbia_lineup = ["Falcao", "J. Cuadrado", "J. Rodríguez", "J. Izquierdo", "J. Lerma", "C. Sánchez", "J. Mojica", "O. Murillo", "D. Sánchez", "S. Arias", "D. Ospina", "J. Quintero", "W. Barrios", "C. Bacca"]
fifa_18.loc[fifa_18.name == columbia_lineup[0], "nation_position"] = "ST"
fifa_18.loc[fifa_18.name == columbia_lineup[1], "nation_position"] = "RW"
fifa_18.loc[fifa_18.name == columbia_lineup[2], "nation_position"] = "CAM"
fifa_18.loc[fifa_18.name == columbia_lineup[3], "nation_position"] = "LW"
fifa_18.loc[fifa_18.name == columbia_lineup[4], "nation_position"] = "CDM"
fifa_18.loc[fifa_18.name == columbia_lineup[5], "nation_position"] = "CDM"
fifa_18.loc[fifa_18.name == columbia_lineup[6], "nation_position"] = "LB"
fifa_18.loc[fifa_18.name == columbia_lineup[7], "nation_position"] = "CB"
fifa_18.loc[fifa_18.name == columbia_lineup[8], "nation_position"] = "CB"
fifa_18.loc[fifa_18.name == columbia_lineup[9], "nation_position"] = "RB"
fifa_18.loc[fifa_18.name == columbia_lineup[10], "nation_position"] = "GK"
fifa_18.loc[fifa_18.name == columbia_lineup[11], "nation_position"] = "SUB"
fifa_18.loc[fifa_18.name == columbia_lineup[12], "nation_position"] = "SUB"
fifa_18.loc[fifa_18.name == columbia_lineup[13], "nation_position"] = "SUB"

# %%
japan_lineup = ["Y. Ōsako", "T. Inui", "S. Kagawa", "G. Haraguchi", "M. Hasebe", "G. Shibasaki", "Y. Nagatomo", "G. Shoji", "M. Yoshida", "H. Sakai", "E. Kawashima", "K. Honda", "S. Okazaki", "H. Yamaguchi"]
fifa_18.loc[fifa_18.name == japan_lineup[0], "nation_position"] = "ST"
fifa_18.loc[fifa_18.name == japan_lineup[1], "nation_position"] = "LW"
fifa_18.loc[fifa_18.name == japan_lineup[2], "nation_position"] = "CAM"
fifa_18.loc[fifa_18.name == japan_lineup[3], "nation_position"] = "RW"
fifa_18.loc[fifa_18.name == japan_lineup[4], "nation_position"] = "CDM"
fifa_18.loc[fifa_18.name == japan_lineup[5], "nation_position"] = "CDM"
fifa_18.loc[fifa_18.name == japan_lineup[6], "nation_position"] = "LB"
fifa_18.loc[fifa_18.name == japan_lineup[7], "nation_position"] = "CB"
fifa_18.loc[fifa_18.name == japan_lineup[8], "nation_position"] = "CB"
fifa_18.loc[fifa_18.name == japan_lineup[9], "nation_position"] = "RB"
fifa_18.loc[fifa_18.name == japan_lineup[10], "nation_position"] = "GK"
fifa_18.loc[fifa_18.name == japan_lineup[11], "nation_position"] = "SUB"
fifa_18.loc[fifa_18.name == japan_lineup[12], "nation_position"] = "SUB"
fifa_18.loc[fifa_18.name == japan_lineup[13], "nation_position"] = "SUB"

# %%
poland_lineup = ["R. Lewandowski", "K. Grosicki", "A. Milik", "J. Blaszczykowski", "G. Krychowiak", "P. Zieliński", "M. Rybus", "M. Pazdan", "Thiago Cionek", "L. Pisczek", "W. Szczęsny", "J. Bednarek", "D. Kownacki", "B. Bereszyński"]
fifa_18.loc[fifa_18.name == poland_lineup[0], "nation_position"] = "ST"
fifa_18.loc[fifa_18.name == poland_lineup[1], "nation_position"] = "LW"
fifa_18.loc[fifa_18.name == poland_lineup[2], "nation_position"] = "CAM"
fifa_18.loc[fifa_18.name == poland_lineup[3], "nation_position"] = "RW"
fifa_18.loc[fifa_18.name == poland_lineup[4], "nation_position"] = "CDM"
fifa_18.loc[fifa_18.name == poland_lineup[5], "nation_position"] = "CDM"
fifa_18.loc[fifa_18.name == poland_lineup[6], "nation_position"] = "LB"
fifa_18.loc[fifa_18.name == poland_lineup[7], "nation_position"] = "CB"
fifa_18.loc[fifa_18.name == poland_lineup[8], "nation_position"] = "CB"
fifa_18.loc[fifa_18.name == poland_lineup[9], "nation_position"] = "RB"
fifa_18.loc[fifa_18.name == poland_lineup[10], "nation_position"] = "GK"
fifa_18.loc[fifa_18.name == poland_lineup[11], "nation_position"] = "SUB"
fifa_18.loc[fifa_18.name == poland_lineup[12], "nation_position"] = "SUB"
fifa_18.loc[fifa_18.name == poland_lineup[13], "nation_position"] = "SUB"

# %%
portugal = fifa_18.loc[fifa_18["nationality"] == "Senegal"]
pd.set_option('display.max_rows', portugal.shape[0]+1)
portugal
# Out:
#                      name nationality                                  club  \
# 100          K. Koulibaly     Senegal                                Napoli
# 103               S. Mané     Senegal                             Liverpool
# 156              I. Gueye     Senegal                               Everton
# 200         K. Baldé Diao     Senegal                             AS Monaco
# 596               S. Sané     Senegal                           Hannover 96
# 762            A. N'Diaye     Senegal               Wolverhampton Wanderers
# 768              K. Mbodj     Senegal                        RSC Anderlecht
# 1001            H. Saivet     Senegal                      Newcastle United
# 1028         Badou Ndiaye     Senegal                        Galatasaray SK
# 1031           C. Kouyaté     Senegal                       West Ham United
# 1158          Y. Sankharé     Senegal              FC Girondins de Bordeaux
# ...

# %%
senegal_lineup = ["M. Leye", "M. Diouf", "S. Mané", "A. N'Diaye", "I. Gueye", "I. Sarr", "A. Mbengue", "K. Koulibaly", "S. Sané", "M. Wagué", "A. Diallo", "C. Kouyaté", "C. N'Doye", "M. Konaté"]
fifa_18.loc[fifa_18.name == senegal_lineup[0], "nation_position"] = "ST"
fifa_18.loc[fifa_18.name == senegal_lineup[1], "nation_position"] = "ST"
fifa_18.loc[fifa_18.name == senegal_lineup[2], "nation_position"] = "LW"
fifa_18.loc[fifa_18.name == senegal_lineup[3], "nation_position"] = "CM"
fifa_18.loc[fifa_18.name == senegal_lineup[4], "nation_position"] = "CM"
fifa_18.loc[fifa_18.name == senegal_lineup[5], "nation_position"] = "RW"
fifa_18.loc[fifa_18.name == senegal_lineup[6], "nation_position"] = "LB"
fifa_18.loc[fifa_18.name == senegal_lineup[7], "nation_position"] = "CB"
fifa_18.loc[fifa_18.name == senegal_lineup[8], "nation_position"] = "CB"
fifa_18.loc[fifa_18.name == senegal_lineup[9], "nation_position"] = "RB"
fifa_18.loc[fifa_18.name == senegal_lineup[10], "nation_position"] = "GK"
fifa_18.loc[fifa_18.name == senegal_lineup[11], "nation_position"] = "SUB"
fifa_18.loc[fifa_18.name == senegal_lineup[12], "nation_position"] = "SUB"
fifa_18.loc[fifa_18.name == senegal_lineup[13], "nation_position"] = "SUB"
